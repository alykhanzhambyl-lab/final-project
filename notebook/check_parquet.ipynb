# %%
yellow_path = "Files/nyc_taxi/yellow/2019/yellow_tripdata_2019-01.parquet"
green_path  = "Files/nyc_taxi/green/2019/green_tripdata_2019-01.parquet"

df_y = spark.read.parquet(yellow_path)
df_g = spark.read.parquet(green_path)

print("yellow:", df_y.count(), len(df_y.columns))
print("green :", df_g.count(), len(df_g.columns))

display(df_y.limit(10))
display(df_g.limit(10))
# Out:
# StatementMeta(, 2f70be2a-0165-4496-a591-42ae993e7bf2, 5, Finished, Available, Finished)
# yellow: 7696617 19
# green : 672105 20
# SynapseWidget(Synapse.DataFrame, 75dd681e-040f-47a1-a474-3bd60bf062e5)
# SynapseWidget(Synapse.DataFrame, 880c9129-74bc-46d9-b40d-2d10654cefe1)
